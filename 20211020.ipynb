# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784).astype('float32')
x_test = x_test.reshape(10000, 784).astype('float32')

x_train /= 255
x_test /= 255

n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_test = to_categorical(y_test, n_classes)
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
#原本
H=[]
model = Sequential()
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='mean_squared_error', 
       optimizer=optimizers.SGD(learning_rate=0.01),
       metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))


H.append(history.history['val_accuracy'][19])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0921 - accuracy: 0.0947 - val_loss: 0.0916 - val_accuracy: 0.0946
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0913 - accuracy: 0.0963 - val_loss: 0.0909 - val_accuracy: 0.0981
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0906 - accuracy: 0.1047 - val_loss: 0.0904 - val_accuracy: 0.1115
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.1253 - val_loss: 0.0899 - val_accuracy: 0.1358
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0897 - accuracy: 0.1509 - val_loss: 0.0895 - val_accuracy: 0.1616
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0893 - accuracy: 0.1793 - val_loss: 0.0891 - val_accuracy: 0.1901
# Epoch 7/20
# ...

# %%
#loss = 'categorical_crossentropy'
model = Sequential()
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
       optimizer=optimizers.SGD(learning_rate=0.01),
       metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

H.append(history.history['val_accuracy'][19])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0600 - accuracy: 0.4897 - val_loss: 1.8057 - val_accuracy: 0.7052
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 1.6104 - accuracy: 0.7260 - val_loss: 1.4059 - val_accuracy: 0.7650
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2745 - accuracy: 0.7788 - val_loss: 1.1257 - val_accuracy: 0.8114
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0465 - accuracy: 0.8105 - val_loss: 0.9406 - val_accuracy: 0.8308
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8940 - accuracy: 0.8300 - val_loss: 0.8150 - val_accuracy: 0.8458
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7884 - accuracy: 0.8422 - val_loss: 0.7265 - val_accuracy: 0.8582
# Epoch 7/20
# ...

# %%
#activation = 'relu'
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='mean_squared_error', 
       optimizer=optimizers.SGD(learning_rate=0.01),
       metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

H.append(history.history['val_accuracy'][19])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0904 - accuracy: 0.1803 - val_loss: 0.0893 - val_accuracy: 0.2172
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.2375 - val_loss: 0.0875 - val_accuracy: 0.2798
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0869 - accuracy: 0.2969 - val_loss: 0.0856 - val_accuracy: 0.3448
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0849 - accuracy: 0.3631 - val_loss: 0.0834 - val_accuracy: 0.4119
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0826 - accuracy: 0.4315 - val_loss: 0.0809 - val_accuracy: 0.4694
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0799 - accuracy: 0.4855 - val_loss: 0.0780 - val_accuracy: 0.5126
# Epoch 7/20
# ...

# %%
#addDense
model = Sequential()
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='mean_squared_error', 
       optimizer=optimizers.SGD(learning_rate=0.01),
       metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

H.append(history.history['val_accuracy'][19])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0927 - accuracy: 0.0904 - val_loss: 0.0917 - val_accuracy: 0.0892
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0912 - accuracy: 0.0904 - val_loss: 0.0910 - val_accuracy: 0.0892
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0908 - accuracy: 0.0904 - val_loss: 0.0906 - val_accuracy: 0.0892
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0905 - accuracy: 0.0902 - val_loss: 0.0904 - val_accuracy: 0.0887
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0903 - accuracy: 0.0984 - val_loss: 0.0903 - val_accuracy: 0.1097
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0902 - accuracy: 0.1193 - val_loss: 0.0902 - val_accuracy: 0.1206
# Epoch 7/20
# ...

# %%
#addDense,activation,loss
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
       optimizer=optimizers.SGD(learning_rate=0.01),
       metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

H.append(history.history['val_accuracy'][19])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 1s 3ms/step - loss: 1.4100 - accuracy: 0.6355 - val_loss: 0.6887 - val_accuracy: 0.8414
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.8617 - val_loss: 0.4311 - val_accuracy: 0.8823
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8863 - val_loss: 0.3627 - val_accuracy: 0.8996
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3614 - accuracy: 0.8977 - val_loss: 0.3270 - val_accuracy: 0.9072
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3321 - accuracy: 0.9043 - val_loss: 0.3043 - val_accuracy: 0.9123
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3107 - accuracy: 0.9104 - val_loss: 0.2875 - val_accuracy: 0.9175
# Epoch 7/20
# ...

# %%
print("未修改 = {:.4f} \n修改loss = {:.4f} \n修改activation = {:.4f} \n修改Dense = {:.4f} \n全部修改 = {:.4f}".format
  (H[0], H[1], H[2], H[3], H[4]))
# Out:
# 未修改 = 0.4089
# 修改loss = 0.8970
# 修改activation = 0.8025
# 修改Dense = 0.1231
# 全部修改 = 0.9466
