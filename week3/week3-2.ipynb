# %%
import numpy as np

def leakyRelu(z):
  return np.where(z>0,z,z/float(100))

# %%
import matplotlib.pyplot as plt

z=np.linspace(-10,5,1000)

plt.grid(True,linestyle = '-',color = 'gray',linewidth = '0.5',axis='both')
plt.plot(z,leakyRelu(z))
plt.show()
