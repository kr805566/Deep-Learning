# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
def f(x, y):
  return(1-(x/2)+x**5+y**3)*np.exp(-x**2-y**2)

# %%
def derivativeX(x, y, h=0.001):
  return (f(x+h,y)-f(x-h,y))/(2*h)
def derivativeY(x, y, h=0.001):
  return (f(x,y+h)-f(x,y-h))/(2*h)

# %%
n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)

XX, YY = np.meshgrid(x,y)

fig, ax = plt.subplots()
plt.close()
ax.set_xlim((-3, 3))
ax.set_ylim((-3, 3))

conf = ax.contourf(XX, YY, f(XX, YY), 8, alpha=0.75, cmap=plt.cm.jet)

con = ax.contour(XX, YY, f(XX, YY), 10, colors=['black'])

ax.clabel(con, inline=True, fontsize=15)

dot, = ax.plot([], [], 'ro')

eta = 0.04
beta = 0.968

w0, w1 = 0, 3
v0 = w0*eta
v1 = w1*eta

wp0, vp0 = w0, v0
wp1, vp1 = w1, v1

def init():
  global w0, w1
  dot.set_data(w0, w1)
  return dot,

def animate(_):
  global w0, w1, v0, v1
  wp0, vp0 = w0, v0
  wp1, vp1 = w1, v1
  v0 = beta*vp0 - eta*derivativeX(w0, w1)
  v1 = beta*vp1 - eta*derivativeY(w0, w1)

  w0 = wp0-v0
  w1 = wp1-v1
  dot.set_data(w0, w1)
  return dot,


anim = animation.FuncAnimation(fig, animate, init_func=init, frames=200, interval=100, blit=True)
rc('animation', html='jshtml')
anim
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print(w0,w1,f(w0,w1))
# Out:
# -0.2104623411719637 -0.024518707310403686 1.0562996785706396

# %%
n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)

XX, YY = np.meshgrid(x,y)

fig, ax = plt.subplots()
plt.close()
ax.set_xlim((-3, 3))
ax.set_ylim((-3, 3))

conf = ax.contourf(XX, YY, f(XX, YY), 8, alpha=0.75, cmap=plt.cm.jet)

con = ax.contour(XX, YY, f(XX, YY), 10, colors=['black'])

ax.clabel(con, inline=True, fontsize=15)

dot, = ax.plot([], [], 'ro')

eta = 0.04
beta = 0.968

w0, w1 = -3, 3
v0 = w0*eta
v1 = w1*eta

wp0, vp0 = w0, v0
wp1, vp1 = w1, v1

def init():
  global w0, w1
  dot.set_data(w0, w1)
  return dot,

def animate(_):
  global w0, w1, v0, v1
  wp0, vp0 = w0, v0
  wp1, vp1 = w1, v1
  v0 = beta*vp0 - eta*derivativeX(w0, w1)
  v1 = beta*vp1 - eta*derivativeY(w0, w1)

  w0 = wp0-v0
  w1 = wp1-v1
  dot.set_data(w0, w1)
  return dot,


anim = animation.FuncAnimation(fig, animate, init_func=init, frames=200, interval=100, blit=True)
rc('animation', html='jshtml')
anim
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print(w0,w1,f(w0,w1))
# Out:
# 1.5729740067376001 0.012986326369570771 0.828909090652247
