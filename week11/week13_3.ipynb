# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.restoration import inpaint

# %%
#!pip uninstall scikit-image
#!pip install scikit-image==0.19.0

# %%
plt.figure(figsize=(8,10))
Img = (plt.imread('/content/drive/MyDrive/Deep Learning/week13/parrot_defect.png')*255).astype('uint8')
plt.imshow(Img[:,:,0:3])

# %%
Img.shape
# Out:
# (512, 768, 4)

# %%
plt.figure(figsize=(8,10))
plt.imshow((Img[:,:,0:3].sum(axis=-1)==255*3),cmap='gray')

# %%
mask=(Img[:,:,0:3].sum(axis=-1)==255*3)
plt.imshow(mask)

# %%
image_result=inpaint.inpaint_biharmonic(Img[:,:,0:3], mask,multichannel=True)

plt.figure(figsize=(8,10))
plt.imshow(image_result)
